# %% [markdown]
# ### Model conversion

# %%
import tensorflow as tf
import numpy as np

# Load keras model
model = tf.keras.models.load_model("../ml-training/models/cnn_deep.h5")

# Convert to TFLite
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]  
tflite_model = converter.convert()

with open("models/tflite/cnn_deep.tflite", "wb") as f:
    f.write(tflite_model)

print(f"Model size: {len(tflite_model) / 1024:.1f} KB")
# Out:
# 2026-05-28 22:37:15.092062: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,127,16]
# 	 [[{{node inputs}}]]
# 2026-05-28 22:37:15.114369: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,63,16]
# 	 [[{{node inputs}}]]
# 2026-05-28 22:37:15.135829: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,31,16]
# 	 [[{{node inputs}}]]
# 2026-05-28 22:37:15.162758: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# 2026-05-28 22:37:15.573530: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,127,16]
# 	 [[{{node inputs}}]]
# 2026-05-28 22:37:15.644183: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,63,16]
# 	 [[{{node inputs}}]]
# 2026-05-28 22:37:15.714250: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,31,16]
# 	 [[{{node inputs}}]]
# 2026-05-28 22:37:15.778565: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _update_step_xla while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /tmp/tmpqq0i4ijz/assets
# INFO:tensorflow:Assets written to: /tmp/tmpqq0i4ijz/assets
# Model size: 28.6 KB
# 2026-05-28 22:37:17.653701: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:364] Ignored output_format.
# 2026-05-28 22:37:17.653758: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:367] Ignored drop_control_dependency.
# 2026-05-28 22:37:17.654084: I tensorflow/cc/saved_model/reader.cc:45] Reading SavedModel from: /tmp/tmpqq0i4ijz
# 2026-05-28 22:37:17.657832: I tensorflow/cc/saved_model/reader.cc:89] Reading meta graph with tags { serve }
# 2026-05-28 22:37:17.657866: I tensorflow/cc/saved_model/reader.cc:130] Reading SavedModel debug info (if present) from: /tmp/tmpqq0i4ijz
# 2026-05-28 22:37:17.668749: I tensorflow/cc/saved_model/loader.cc:231] Restoring SavedModel bundle.
# 2026-05-28 22:37:17.742036: I tensorflow/cc/saved_model/loader.cc:215] Running initialization op on SavedModel bundle at path: /tmp/tmpqq0i4ijz
# 2026-05-28 22:37:17.772905: I tensorflow/cc/saved_model/loader.cc:314] SavedModel load for tags { serve }; Status: success: OK. Took 118821 microseconds.

# %%
model.summary()
# Out:
# Model: "sequential_24"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_22 (Conv1D)          (None, 254, 16)           128
#
#  max_pooling1d_22 (MaxPoolin  (None, 127, 16)          0
#  g1D)
#
#  dropout_61 (Dropout)        (None, 127, 16)           0
#
#  conv1d_23 (Conv1D)          (None, 127, 16)           1296
#
#  max_pooling1d_23 (MaxPoolin  (None, 63, 16)           0
#  g1D)
#
#  dropout_62 (Dropout)        (None, 63, 16)            0
#
#  conv1d_24 (Conv1D)          (None, 63, 16)            784
#
#  max_pooling1d_24 (MaxPoolin  (None, 31, 16)           0
#  g1D)
#
#  dropout_63 (Dropout)        (None, 31, 16)            0
#
#  flatten_9 (Flatten)         (None, 496)               0
#
#  dense_68 (Dense)            (None, 32)                15904
#
#  dropout_64 (Dropout)        (None, 32)                0
#
#  dense_69 (Dense)            (None, 6)                 198
#
# =================================================================
# Total params: 18,310
# Trainable params: 18,310
# Non-trainable params: 0
# _________________________________________________________________
